# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#%matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],'ro')

# %%
plt.plot([1,5,4,9],linewidth=5.0)
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
plt.scatter(df['Rainfall'],df['Humidity3pm'])

# %%
plt.plot(df['Humidity3pm'])

# %%
plt.hist(df['Humidity9am'])
# Out:
# (array([ 4., 16., 16., 38., 48., 78., 73., 40., 29., 24.]),
#  array([36. , 42.3, 48.6, 54.9, 61.2, 67.5, 73.8, 80.1, 86.4, 92.7, 99. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df['Humidity3pm'],kde=True)
# Out:
# C:\Users\Sakshi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['MaxTemp'],hist=False,kde=True,rug=True) #hist f

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['MaxTemp'], df['Humidity3pm'])

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['MaxTemp'], df['Humidity3pm'],shade=True)

# %%
sns.jointplot(df['MaxTemp'], df['Humidity3pm'])
# Out:
# C:\Users\Sakshi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Sakshi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x='Rainfall',y='Humidity3pm',data = df)

# %%
sns.jointplot(df['MaxTemp'], df['Humidity3pm'],kind='hex',color='b')
# Out:
# C:\Users\Sakshi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Sakshi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(df['MaxTemp'], df['Humidity3pm'],kind='kde',color='r')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(10,8))
sns.stripplot(x='time',y='total_bill',data = tips)

# %%
plt.figure(figsize=(10,8))
sns.swarmplot(x='time',y='total_bill',data = tips)

# %%
sns.boxplot(x='time',y='total_bill',data = tips)

# %%
plt.figure(figsize=(10,8))
corr = df.corr()
sns.heatmap(corr)
